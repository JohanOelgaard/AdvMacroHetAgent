# %% [markdown]
# # HANC 2 types of labour

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - 1. [Setup](#toc1_)
# - 2. [Solve household problem](#toc2_)
# - 3. [Find stationary equilibrium](#toc3_)
#   - 3.1. [Direct approach](#toc3_1_)
#   - 3.2. [Looking at the stationary equilibrium](#toc3_2_)
#     - 3.2.1. [Policy functions](#toc3_2_1_)
#     - 3.2.2. [Distributions](#toc3_2_2_)
#   - 3.3. [Indirect approach](#toc3_3_)
# - 4. [Idiosyncratic risk and the steady state interest rate](#toc4_)
# - 5. [Calibration](#toc5_)
# - 6. [Extra: Demand vs. supply of capital](#toc6_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=true
# 	anchor=true
# 	flat=false
# 	minLevel=2
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# **Import stuff**

# %%
# %load_ext autoreload
# %autoreload 2
from copy import deepcopy
import time
import pickle
import numpy as np
from scipy import optimize

import matplotlib.pyplot as plt   
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
plt.rcParams.update({"axes.grid" : True, "grid.color": "black", "grid.alpha":"0.25", "grid.linestyle": "--"})
plt.rcParams.update({'font.size': 14})

from HANCModel import HANCModelClass

# %% [markdown]
# ## 1. <a id='toc1_'></a>[Setup](#toc0_)

# %%
model = HANCModelClass(name='baseline') # create an instance of the model
par = model.par
ss = model.ss

# %%
model.info(only_blocks=True)
model.draw_DAG(figsize=(10,10))
# Out:
# production_firm: [K,phi0,phi1] -> [rK,w0,w1,Y,L]
# hh: [phi0,phi1,rK,w0,w1] -> [A_hh,C_hh,L_hh]
# market_clearing: [A_hh,L,L_hh,Y,C_hh,K] -> [A,I,clearing_A,clearing_L,clearing_Y]

# %% [markdown]
# ## 2. <a id='toc3_'></a>[Find stationary equilibrium](#toc0_)

# %%
ss = model.ss
ss.phi1 = 2.0

# %%
model.find_ss(method='direct',do_print=True)
# Out:
# ### step 1: broad search ###
#
# guess ss.K = 1.0000
# implied ss.rK = 0.2777
# implied ss.w1 = 0.3703
# implied ss.w0 = 0.3703
# household problem in ss solved in 1.4 secs [342 iterations]
# household problem in ss simulated in 1.0 secs [113 iterations]
# implied ss.A_hh = 535.9821
# clearing_A = -534.98213157
#
# guess ss.K = 2.0000
# implied ss.rK = 0.1782
# implied ss.w1 = 0.4752
# implied ss.w0 = 0.4752
# household problem in ss solved in 0.2 secs [616 iterations]
# household problem in ss simulated in 0.1 secs [371 iterations]
# implied ss.A_hh = 512.8555
# clearing_A = -510.85553541
#
# guess ss.K = 3.0000
# implied ss.rK = 0.1375
# implied ss.w1 = 0.5499
# implied ss.w0 = 0.5499
# household problem in ss solved in 0.4 secs [1031 iterations]
# household problem in ss simulated in 1.5 secs [13625 iterations]
# implied ss.A_hh = 502.9870
# clearing_A = -499.98702101
#
# guess ss.K = 4.0000
# implied ss.rK = 0.1144
# implied ss.w1 = 0.6099
# implied ss.w0 = 0.6099
# household problem in ss solved in 0.6 secs [1725 iterations]
# household problem in ss simulated in 1.2 secs [12092 iterations]
# implied ss.A_hh = 11.7004
# clearing_A =  -7.70036885
#
# guess ss.K = 5.0000
# implied ss.rK = 0.0991
# implied ss.w1 = 0.6610
# implied ss.w0 = 0.6610
# household problem in ss solved in 0.2 secs [604 iterations]
# household problem in ss simulated in 0.1 secs [417 iterations]
# implied ss.A_hh = 0.5716
# clearing_A =   4.42843022
#
# guess ss.K = 6.0000
# implied ss.rK = 0.0882
# implied ss.w1 = 0.7058
# implied ss.w0 = 0.7058
# household problem in ss solved in 0.1 secs [373 iterations]
# household problem in ss simulated in 0.0 secs [245 iterations]
# implied ss.A_hh = 0.2009
# clearing_A =   5.79909882
#
# guess ss.K = 7.0000
# implied ss.rK = 0.0799
# implied ss.w1 = 0.7461
# implied ss.w0 = 0.7461
# household problem in ss solved in 0.1 secs [285 iterations]
# household problem in ss simulated in 0.0 secs [181 iterations]
# implied ss.A_hh = 0.0937
# clearing_A =   6.90633261
#
# guess ss.K = 8.0000
# implied ss.rK = 0.0734
# implied ss.w1 = 0.7828
# implied ss.w0 = 0.7828
# household problem in ss solved in 0.1 secs [239 iterations]
# household problem in ss simulated in 0.0 secs [149 iterations]
# implied ss.A_hh = 0.0506
# clearing_A =   7.94937485
#
# guess ss.K = 9.0000
# implied ss.rK = 0.0681
# implied ss.w1 = 0.8167
# implied ss.w0 = 0.8167
# household problem in ss solved in 0.1 secs [209 iterations]
# household problem in ss simulated in 0.0 secs [129 iterations]
# implied ss.A_hh = 0.0302
# clearing_A =   8.96980190
#
# guess ss.K = 10.0000
# implied ss.rK = 0.0636
# implied ss.w1 = 0.8483
# implied ss.w0 = 0.8483
# household problem in ss solved in 0.1 secs [188 iterations]
# household problem in ss simulated in 0.0 secs [113 iterations]
# implied ss.A_hh = 0.0195
# clearing_A =   9.98050519
#
# ### step 2: determine search bracket ###
#
# K in [  4.00000000,  5.00000000]
#
# ### step 3: search ###
#
#   0: K_ss =   4.63488304 -> A-A_hh =   3.65441815
#   1: K_ss =   4.31744152 -> A-A_hh =   2.41508856
#   2: K_ss =   4.15872076 -> A-A_hh =   0.92784519
#   3: K_ss =   4.07936038 -> A-A_hh =  -0.88777924
#   4: K_ss =   4.11816494 -> A-A_hh =   0.19225330
#   5: K_ss =   4.11125745 -> A-A_hh =   0.03469794
#   6: K_ss =   4.10979346 -> A-A_hh =  -0.00026265
#   7: K_ss =   4.10980446 -> A-A_hh =   0.00000215
#   8: K_ss =   4.10980437 -> A-A_hh =   0.00000000
#   9: K_ss =   4.10980437 -> A-A_hh =   0.00000000
#  10: K_ss =   4.10980437 -> A-A_hh =  -0.00000000
#
# K_ss =   4.10980437 [A-A_hh =   0.00000000]
#
# found steady state in 18.9 secs

# %% [markdown]
# **Look at the steady state variables:**

# %%
for varname in model.varlist:
    print(f'{varname:15s}: {ss.__dict__[varname]:.4f}')
# Out:
# K              : 4.1098
# phi0           : 1.0000
# phi1           : 2.0000
# rK             : 0.1124
# w0             : 0.6159
# w1             : 0.6159
# Y              : 1.2831
# L              : 1.3333
# A_hh           : 4.1098
# C_hh           : 0.8722
# L_hh           : 1.3333
# A              : 4.1098
# I              : 0.4110
# clearing_A     : 0.0000
# clearing_L     : 0.0000
# clearing_Y     : 0.0000

# %% [markdown]
# ### 3.2. <a id='toc3_2_'></a>[Looking at the stationary equilibrium](#toc0_)

# %% [markdown]
# #### 3.2.1. <a id='toc3_2_1_'></a>[Policy functions](#toc0_)

# %%
for i_beta, beta in enumerate(par.beta_grid):

    # Skip plotting for the 1st, 3rd, and 6th beta values
    if i_beta in [0, 3, 5]:
        continue
    
    fig = plt.figure(figsize=(12, 4), dpi=100)

    I = par.a_grid < 500

    # a. consumption
    ax = fig.add_subplot(1, 2, 1)
    ax.set_title(f'consumption ($\\beta = {beta:.4f}, \\chi = {par.j_grid[i_beta]}$) ')

    for i_z, z in enumerate(par.z_grid):
        if i_z % 3 == 0 or i_z == par.Nz - 1:
            ax.plot(par.a_grid[I], ss.c[i_beta, i_z, I], label=f'z = {z:.2f}')

    ax.legend(frameon=True)
    ax.set_xlabel('savings, $a_{t-1}$')
    ax.set_ylabel('consumption, $c_t$')
    ax.set_xlim(0, 100)
    ax.set_ylim(0, 5)

    # b. saving
    ax = fig.add_subplot(1, 2, 2)
    ax.set_title(f'saving ($\\beta = {beta:.4f}, \\chi = {par.j_grid[i_beta]}$)')

    for i_z, z in enumerate(par.z_grid):
        if i_z % 3 == 0 or i_z == par.Nz - 1:
            ax.plot(par.a_grid[I], ss.a[i_beta, i_z, I] - par.a_grid[I], label=f'z = {z:.2f}')

    ax.set_xlabel('savings, $a_{t-1}$')
    ax.set_ylabel('savings change, $a_{t}-a_{t-1}$')
    ax.set_xlim(0, 100)
    ax.set_ylim(-2.5, 1.5)

    fig.tight_layout()
    #fig.savefig(f'figs/c_func_{i_beta}.pdf')

# %% [markdown]
# #### 3.2.2. <a id='toc3_2_2_'></a>[Distributions](#toc0_)

# %%
fig = plt.figure(figsize=(12,4),dpi=100)

# b. assets
ax = fig.add_subplot(1,2,2)
ax.set_title('savings')
for i_beta,beta in enumerate(par.beta_grid):
    if i_beta in [1, 4, 6]:
        continue
    ax.plot(np.insert(par.a_grid,0,par.a_grid[0]),np.insert(np.cumsum(np.sum(ss.D[i_beta],axis=0)),0,0.0)*par.Nfix, label = f'$\\beta = {beta:.4f}, \\chi = {par.j_grid[i_beta]}$')
ax.set_xlabel('assets, $a_{t}$')
ax.set_ylabel('CDF')
ax.set_xscale('symlog')
ax.legend(loc = 'lower right', fontsize = 'small')

fig.tight_layout()

# %% [markdown]
# ### 3.3. <a id='toc3_2_'></a>[Tests](#toc0_)

# %%
model.test_hh_path()
# Out:
# note: inputs = steady state value -> expected: constant value (straigt line)
#
# household problem solved along transition path in 0.4 secs
# household problem simulated along transition in 0.3 secs

# %%
model.test_path()
# Out:
# shocks: phi1 phi0
# unknowns: K
#
# blocks.production_firm
#  rK               0.0e+00
#  w0               0.0e+00
#  w1               1.1e-16
#  Y                0.0e+00
#  L                0.0e+00
# hh
#  A_hh             3.6e-07
#  C_hh             6.5e-09
#  L_hh             4.0e-15
# blocks.market_clearing
#  A                0.0e+00
#  I                    nan
#  clearing_A       3.6e-07 [target]
#  clearing_L       4.0e-15
#  clearing_Y       6.5e-09

# %% [markdown]
# ## 4. <a id='toc4_'></a>[Find Transition Path Temporary Shock](#toc0_)

# %%
model.compute_jacs(do_print=True)
# Out:
# household Jacobians:
# one step deviation from steady state calculated in 0.0 secs
# curly_Y and curly_D calculated for phi0            in 0.4 secs
# curly_Y and curly_D calculated for phi1            in 0.4 secs
# curly_Y and curly_D calculated for rK              in 0.4 secs
# curly_Y and curly_D calculated for w0              in 0.4 secs
# curly_Y and curly_D calculated for w1              in 0.4 secs
# curly_E calculated in 0.8 secs
# builiding blocks combined in 2.2 secs
# household Jacobian computed in 5.0 secs
#
# full Jacobians:
# full Jacobian to unknowns computed in 0.5 secs [in evaluate_blocks(): 0.1 secs]
# full Jacobian to shocks computed in 0.3 secs [in evaluate_blocks(): 0.2 secs]

# %% [markdown]
# ### 4.1. <a id='toc3_2_'></a>[Jacobians of household block wrt. $\phi_1$](#toc0_)

# %%
fig = plt.figure(figsize=(12,4),dpi=100)

i = 0
    
# a. savings
i += 1    
ax = fig.add_subplot(1,2,i)
ax.set_title(f'savings, $a_t$, to $\phi1$')
for s in [0,50,150,250]:
    jac_hh_var = model.jac_hh[('A_hh','phi1')]
    ax.plot(np.arange(par.T),jac_hh_var[:,s],label=f'shock at {s}')

# b. consumption
i += 1    
ax = fig.add_subplot(1,2,i)
ax.set_title(f'consumption, $c_t$, to $\phi1$')
for s in [0,50,150,250]:
    jac_hh_var = model.jac_hh[('C_hh','phi1')]
    ax.plot(np.arange(par.T),jac_hh_var[:,s],label=f'shock at {s}')
ax.legend(loc = 'upper right', fontsize = 'small')

# %%
# a. define shock
dphi1 = np.zeros(par.T)
dphi1[0:9] = 0.1*ss.phi1
shocks = {'dphi1':dphi1} 

# b. find transition path
model.find_transition_path(do_print=True,shocks=shocks)
# Out:
# finding the transition path:
#  it =   0 -> max. abs. error = 2.91e-01
#  it =   1 -> max. abs. error = 4.61e-03
#  it =   2 -> max. abs. error = 1.23e-04
#  it =   3 -> max. abs. error = 7.48e-07
#  it =   4 -> max. abs. error = 3.92e-09
#  it =   5 -> max. abs. error = 1.04e-11
# I: terminal value is   0.00000000, but ss value is   0.41098044
#
# transition path found in 3.7 secs

# %%
paths = ['Y','K','rK','w0','w1']
model.show_IRFs(paths,ncols=3,T_max=100)
# Out:
# ### shocks ###
# ### varnames ###
# ### tagets ###

# %% [markdown]
# ## 5. <a id='toc5_'></a>[Find Transition Path Permenant Shock](#toc0_)

# %%
new_model = model.copy()

# %%
ss = new_model.ss
ss.phi1 = 2.2

# %%
new_model.find_ss(method='direct',do_print=True)
# Out:
# ### step 1: broad search ###
#
# guess ss.K = 1.0000
# implied ss.rK = 0.2863
# implied ss.w1 = 0.3471
# implied ss.w0 = 0.3818
# household problem in ss solved in 0.2 secs [325 iterations]
# household problem in ss simulated in 0.0 secs [107 iterations]
# implied ss.A_hh = 537.9423
# clearing_A = -536.94230599
#
# guess ss.K = 2.0000
# implied ss.rK = 0.1837
# implied ss.w1 = 0.4454
# implied ss.w0 = 0.4900
# household problem in ss solved in 0.3 secs [594 iterations]
# household problem in ss simulated in 0.0 secs [313 iterations]
# implied ss.A_hh = 514.1788
# clearing_A = -512.17878337
#
# guess ss.K = 3.0000
# implied ss.rK = 0.1417
# implied ss.w1 = 0.5154
# implied ss.w0 = 0.5670
# household problem in ss solved in 0.4 secs [960 iterations]
# household problem in ss simulated in 0.4 secs [3131 iterations]
# implied ss.A_hh = 504.0470
# clearing_A = -501.04702801
#
# guess ss.K = 4.0000
# implied ss.rK = 0.1179
# implied ss.w1 = 0.5717
# implied ss.w0 = 0.6288
# household problem in ss solved in 1.0 secs [1569 iterations]
# household problem in ss simulated in 0.5 secs [5044 iterations]
# implied ss.A_hh = 168.4530
# clearing_A = -164.45304883
#
# guess ss.K = 5.0000
# implied ss.rK = 0.1022
# implied ss.w1 = 0.6195
# implied ss.w0 = 0.6814
# household problem in ss solved in 0.3 secs [720 iterations]
# household problem in ss simulated in 0.1 secs [517 iterations]
# implied ss.A_hh = 0.8311
# clearing_A =   4.16894967
#
# guess ss.K = 6.0000
# implied ss.rK = 0.0910
# implied ss.w1 = 0.6615
# implied ss.w0 = 0.7277
# household problem in ss solved in 0.1 secs [412 iterations]
# household problem in ss simulated in 0.0 secs [275 iterations]
# implied ss.A_hh = 0.2710
# clearing_A =   5.72900226
#
# guess ss.K = 7.0000
# implied ss.rK = 0.0824
# implied ss.w1 = 0.6992
# implied ss.w0 = 0.7692
# household problem in ss solved in 0.1 secs [307 iterations]
# household problem in ss simulated in 0.0 secs [197 iterations]
# implied ss.A_hh = 0.1236
# clearing_A =   6.87637212
#
# guess ss.K = 8.0000
# implied ss.rK = 0.0757
# implied ss.w1 = 0.7337
# implied ss.w0 = 0.8071
# household problem in ss solved in 0.1 secs [252 iterations]
# household problem in ss simulated in 0.0 secs [158 iterations]
# implied ss.A_hh = 0.0660
# clearing_A =   7.93403598
#
# guess ss.K = 9.0000
# implied ss.rK = 0.0702
# implied ss.w1 = 0.7655
# implied ss.w0 = 0.8420
# household problem in ss solved in 0.1 secs [219 iterations]
# household problem in ss simulated in 0.0 secs [138 iterations]
# implied ss.A_hh = 0.0388
# clearing_A =   8.96124515
#
# guess ss.K = 10.0000
# implied ss.rK = 0.0656
# implied ss.w1 = 0.7951
# implied ss.w0 = 0.8746
# household problem in ss solved in 0.1 secs [196 iterations]
# household problem in ss simulated in 0.0 secs [120 iterations]
# implied ss.A_hh = 0.0249
# clearing_A =   9.97512838
#
# ### step 2: determine search bracket ###
#
# K in [  4.00000000,  5.00000000]
#
# ### step 3: search ###
#
#   0: K_ss =   4.97527636 -> A-A_hh =   4.11361814
#   1: K_ss =   4.48763818 -> A-A_hh =   2.26556768
#   2: K_ss =   4.24381909 -> A-A_hh =  -2.54525855
#   3: K_ss =   4.37281619 -> A-A_hh =   1.13334917
#   4: K_ss =   4.29329058 -> A-A_hh =  -0.45390806
#   5: K_ss =   4.31603253 -> A-A_hh =   0.13171135
#   6: K_ss =   4.31091765 -> A-A_hh =   0.01251608
#   7: K_ss =   4.31039497 -> A-A_hh =  -0.00003206
#   8: K_ss =   4.31039631 -> A-A_hh =   0.00000009
#   9: K_ss =   4.31039630 -> A-A_hh =   0.00000000
#  10: K_ss =   4.31039630 -> A-A_hh =  -0.00000000
#
# K_ss =   4.31039630 [A-A_hh =   0.00000000]
#
# found steady state in 15.5 secs

# %%
for varname in new_model.varlist:
    print(f'{varname:15s}: {ss.__dict__[varname]:.4f}')
# Out:
# K              : 4.3104
# phi0           : 1.0000
# phi1           : 2.2000
# rK             : 0.1124
# w0             : 0.6460
# w1             : 0.5872
# Y              : 1.3458
# L              : 1.4000
# A_hh           : 4.3104
# C_hh           : 0.9147
# L_hh           : 1.4000
# A              : 4.3104
# I              : 0.4310
# clearing_A     : 0.0000
# clearing_L     : 0.0000
# clearing_Y     : 0.0000

# %%
new_model.compute_jacs(do_print=True) # if skip_shocks = True the full Jacobians to shocks are not computed
# Out:
# household Jacobians:
# one step deviation from steady state calculated in 0.0 secs
# curly_Y and curly_D calculated for phi0            in 0.5 secs
# curly_Y and curly_D calculated for phi1            in 0.4 secs
# curly_Y and curly_D calculated for rK              in 0.4 secs
# curly_Y and curly_D calculated for w0              in 0.4 secs
# curly_Y and curly_D calculated for w1              in 0.4 secs
# curly_E calculated in 0.2 secs
# builiding blocks combined in 2.9 secs
# household Jacobian computed in 5.3 secs
#
# full Jacobians:
# full Jacobian to unknowns computed in 0.8 secs [in evaluate_blocks(): 0.1 secs]
# full Jacobian to shocks computed in 0.6 secs [in evaluate_blocks(): 0.3 secs]

# %%
# a. define shock
dphi1 = np.zeros(par.T)
dphi1[0] = -0.2
shocks = {'dphi1':dphi1} 

# b. find transition path
new_model.find_transition_path(do_print=True,shocks=shocks)
# Out:
# finding the transition path:
#  it =   0 -> max. abs. error = 3.48e-02
#  it =   1 -> max. abs. error = 2.68e-05
#  it =   2 -> max. abs. error = 1.03e-07
#  it =   3 -> max. abs. error = 7.90e-11
# I: terminal value is   0.00000000, but ss value is   0.43103963
#
# transition path found in 2.7 secs

# %%
paths = ['Y','K','rK','w0','w1']
new_model.show_IRFs(paths,ncols=3,T_max=100)
# Out:
# ### shocks ###
# ### varnames ###
# ### tagets ###
